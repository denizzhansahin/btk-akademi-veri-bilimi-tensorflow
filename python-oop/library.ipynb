# %%
import numpy

# %%
import matplotlib.pyplot #as matplot

# %%
maasListesi = numpy.random.normal(4000,500,1000) #standart sapması 500 olan, normal dağılım olan, 4000 civarında 1000 tane eleman

# %%
numpy.mean(maasListesi)
# Out:
# 4016.6202506261807

# %%
matplotlib.pyplot.hist(maasListesi,50)
# Out:
# (array([ 2.,  0.,  1.,  2.,  1.,  1.,  7.,  4.,  9., 11., 13., 17., 27.,
#         28., 27., 41., 46., 43., 56., 68., 56., 58., 53., 66., 46., 64.,
#         47., 44., 32., 36., 26., 14., 11., 10., 11.,  8.,  3.,  3.,  1.,
#          3.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([2399.75770128, 2474.31046146, 2548.86322165, 2623.41598184,
#         2697.96874202, 2772.52150221, 2847.0742624 , 2921.62702258,
#         2996.17978277, 3070.73254296, 3145.28530315, 3219.83806333,
#         3294.39082352, 3368.94358371, 3443.49634389, 3518.04910408,
#         3592.60186427, 3667.15462446, 3741.70738464, 3816.26014483,
#         3890.81290502, 3965.3656652 , 4039.91842539, 4114.47118558,
#         4189.02394576, 4263.57670595, 4338.12946614, 4412.68222633,
#         4487.23498651, 4561.7877467 , 4636.34050689, 4710.89326707,
#         4785.44602726, 4859.99878745, 4934.55154764, 5009.10430782,
#         5083.65706801, 5158.2098282 , 5232.76258838, 5307.31534857,
# ...

# %%
matplotlib.pyplot.show()

# %%
import matplotlib.pyplot as matplot

# %%
matplot.hist(maasListesi,50)
# Out:
# (array([ 2.,  0.,  1.,  2.,  1.,  1.,  7.,  4.,  9., 11., 13., 17., 27.,
#         28., 27., 41., 46., 43., 56., 68., 56., 58., 53., 66., 46., 64.,
#         47., 44., 32., 36., 26., 14., 11., 10., 11.,  8.,  3.,  3.,  1.,
#          3.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([2399.75770128, 2474.31046146, 2548.86322165, 2623.41598184,
#         2697.96874202, 2772.52150221, 2847.0742624 , 2921.62702258,
#         2996.17978277, 3070.73254296, 3145.28530315, 3219.83806333,
#         3294.39082352, 3368.94358371, 3443.49634389, 3518.04910408,
#         3592.60186427, 3667.15462446, 3741.70738464, 3816.26014483,
#         3890.81290502, 3965.3656652 , 4039.91842539, 4114.47118558,
#         4189.02394576, 4263.57670595, 4338.12946614, 4412.68222633,
#         4487.23498651, 4561.7877467 , 4636.34050689, 4710.89326707,
#         4785.44602726, 4859.99878745, 4934.55154764, 5009.10430782,
#         5083.65706801, 5158.2098282 , 5232.76258838, 5307.31534857,
# ...

# %%
matplot.show()
