# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#grafikleri daha iyi göstermeyi sağlar

# %%
#bazen plt.show yazmayı gerektirmez

# %%
yasListesi = [10,20,30,30,30,40,50,60,70,75]

# %%
kiloListesi = [20,60,80,85,86,87,70,90,95,90]

# %%
numpyYasListesi = np.array(yasListesi)
numpyKiloListesi = np.array(kiloListesi)

# %%
numpyYasListesi
# Out:
# array([10, 20, 30, 30, 30, 40, 50, 60, 70, 75])

# %%
numpyKiloListesi
# Out:
# array([20, 60, 80, 85, 86, 87, 70, 90, 95, 90])

# %%
plt.plot(numpyYasListesi,numpyKiloListesi,"g") #green ile çiz

# %%
plt.plot(numpyYasListesi,numpyKiloListesi,"r")

# %%
plt.plot(numpyKiloListesi,numpyYasListesi,"y")

# %%
plt.plot(numpyYasListesi,numpyKiloListesi,"y")
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.show()

# %%
plt.plot(numpyYasListesi,numpyKiloListesi,"y")
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.title("Kilo'nun Yaşa Göre Grafiği")
plt.show()
