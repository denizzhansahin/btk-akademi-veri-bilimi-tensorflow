# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
numpyDizisi1 = np.linspace(0,10,20)
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
#scatter
plt.scatter(numpyDizisi1,numpyDizisi2)

# %%
#histogram
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([62, 22, 87, 10, 79, 77, 57, 92, 86, 55, 84, 98, 24, 12, 21,  0, 47,
#        88, 29, 80, 27, 66, 29, 34, 55, 43, 75, 96, 69, 33, 12, 42, 31, 45,
#        92, 51, 33, 35, 43, 17, 82, 54, 70, 80, 95, 49, 40, 87, 17, 22])

# %%
plt.hist(yeniDizi)
# Out:
# (array([1., 5., 7., 5., 6., 6., 2., 4., 9., 5.]),
#  array([ 0. ,  9.8, 19.6, 29.4, 39.2, 49. , 58.8, 68.6, 78.4, 88.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
#boxplot
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a8f0ab460>,
#   <matplotlib.lines.Line2D at 0x7f2a8f0abb50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a8fa217f0>,
#   <matplotlib.lines.Line2D at 0x7f2a8fa21250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a8f0ab940>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a8fa21dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a8fa210a0>],
#  'means': []}

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a8f14f190>,
#   <matplotlib.lines.Line2D at 0x7f2a8f14f490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a8f14faf0>,
#   <matplotlib.lines.Line2D at 0x7f2a8f2d5d60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a8f2dbe20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a8f2d57f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a8f2d5910>],
#  'means': []}

# %%
plt.boxplot(yeniDizi*10)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2a8f2a63a0>,
#   <matplotlib.lines.Line2D at 0x7f2a8f2a69d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2a8f2a6d30>,
#   <matplotlib.lines.Line2D at 0x7f2a8f2a60a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2a8f2a6700>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2a8f290400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2a8f290be0>],
#  'means': []}
